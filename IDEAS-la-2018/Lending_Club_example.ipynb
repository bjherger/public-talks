# %% [markdown]
# # Getting started
#
# Borrowed from: [https://github.com/bjherger/keras-pandas/blob/master/examples/lending_club.py](https://github.com/bjherger/keras-pandas/blob/master/examples/lending_club.py)
#
# We'll install `keras-pandas`
#
# ```bash
# pip install -U keras-pandas
# ```

# %% [markdown]
# ## Setup

# %%
import logging

from keras import Model
from keras.layers import Dense

from keras_pandas.Automater import Automater
from keras_pandas.lib import load_lending_club
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %% [markdown]
# ## Data
#
# Let's say we want to look at the [Lending Club data set]()

# %%
test_run = True

observations = load_lending_club()

if test_run:
    observations = observations.sample(n=100)

observations
# Out:
# /anaconda3/lib/python3.6/site-packages/keras_pandas/lib.py:160: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   observations = pandas.read_csv(file_path, compression='zip', skiprows=1, skipfooter=4, skip_blank_lines=True)
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 31825  NaN        NaN     7000.0       7000.0      5975.000000   36 months
# 15707  NaN        NaN    15000.0      15000.0     14750.000000   60 months
# 39768  NaN        NaN     5100.0       5100.0       575.000000   36 months
# 23243  NaN        NaN     1200.0       1200.0      1200.000000   36 months
# 26010  NaN        NaN     8000.0       8000.0      8000.000000   36 months
# 23207  NaN        NaN    12000.0       7600.0      7600.000000   60 months
# 22347  NaN        NaN    16750.0      16750.0     16750.000000   60 months
# 40417  NaN        NaN     5500.0       5500.0      5017.788782   36 months
# 25095  NaN        NaN     2000.0       2000.0      2000.000000   36 months
# 24898  NaN        NaN     3000.0       3000.0      3000.000000   36 months
# 9909   NaN        NaN     3000.0       3000.0      2725.000000   36 months
# 8173   NaN        NaN     4000.0       4000.0      4000.000000   36 months
# 25909  NaN        NaN     8000.0       8000.0      7850.000000   60 months
# 39272  NaN        NaN     3000.0       3000.0      2675.000000   36 months
# 3144   NaN        NaN    14000.0      14000.0     14000.000000   36 months
# 16968  NaN        NaN    15000.0      15000.0     15000.000000   36 months
# 5317   NaN        NaN    13225.0      13225.0     13225.000000   36 months
# 12631  NaN        NaN    25000.0      25000.0     25000.000000   60 months
# 31908  NaN        NaN     5000.0       5000.0      5000.000000   36 months
# 18226  NaN        NaN     8000.0       8000.0      8000.000000   36 months
# 15091  NaN        NaN     9000.0       9000.0      9000.000000   36 months
# 6985   NaN        NaN     4000.0       4000.0      4000.000000   60 months
# 9681   NaN        NaN     3000.0       3000.0      3000.000000   36 months
# 12735  NaN        NaN    13000.0      13000.0     12750.000000   36 months
# 25114  NaN        NaN     5000.0       5000.0      4966.930000   36 months
# 6568   NaN        NaN    12000.0      12000.0     12000.000000   60 months
# 5776   NaN        NaN    17500.0      17500.0     17500.000000   60 months
# 23571  NaN        NaN    25000.0      25000.0     24775.000000   36 months
# 23047  NaN        NaN     8000.0       8000.0      7925.000000   36 months
# 27504  NaN        NaN     1500.0       1500.0      1500.000000   36 months
# ...    ...        ...        ...          ...              ...         ...
# 35216  NaN        NaN     9000.0       9000.0      8913.319731   36 months
# 42054  NaN        NaN    18875.0      18875.0      5725.000000   36 months
# 27390  NaN        NaN    10000.0      10000.0      9925.000000   60 months
# 14045  NaN        NaN     5600.0       5600.0      5600.000000   36 months
# 4556   NaN        NaN    21000.0      21000.0     20750.000000   36 months
# 35667  NaN        NaN     6000.0       6000.0      5811.916438   36 months
# 5244   NaN        NaN     5000.0       5000.0      5000.000000   60 months
# 16493  NaN        NaN     2125.0       2125.0      2125.000000   36 months
# 36682  NaN        NaN     6000.0       6000.0      4929.141372   36 months
# 27431  NaN        NaN     7500.0       7500.0      7500.000000   36 months
# 15677  NaN        NaN     3500.0       3500.0      3500.000000   60 months
# 12054  NaN        NaN     5600.0       5600.0      5600.000000   36 months
# 33025  NaN        NaN    15000.0      15000.0     14975.000000   36 months
# 75     NaN        NaN    12000.0      12000.0     12000.000000   36 months
# 37088  NaN        NaN     7000.0       7000.0      3584.795098   36 months
# 26204  NaN        NaN    15000.0      15000.0     14800.000000   36 months
# 33051  NaN        NaN    20000.0      20000.0     19775.000000   36 months
# 24322  NaN        NaN    12250.0      12250.0     12250.000000   36 months
# 35457  NaN        NaN    12800.0      12800.0     12542.765331   36 months
# 18620  NaN        NaN     8000.0       8000.0      8000.000000   60 months
# 39369  NaN        NaN     4000.0       4000.0       975.000000   36 months
# 34147  NaN        NaN    21600.0      21600.0     21093.375715   36 months
# 22430  NaN        NaN     6000.0       6000.0      5975.000000   36 months
# 10311  NaN        NaN     7500.0       7500.0      7500.000000   36 months
# 9093   NaN        NaN    35000.0      35000.0     33500.000000   60 months
# 5151   NaN        NaN    12000.0      12000.0     11975.000000   60 months
# 6616   NaN        NaN     5000.0       5000.0      4750.000000   36 months
# 40874  NaN        NaN     9600.0       9600.0      9450.000000   36 months
# 37596  NaN        NaN    15000.0      15000.0     14371.090657   36 months
# 20631  NaN        NaN     7000.0       7000.0      7000.000000   36 months
#
#        int_rate  installment grade sub_grade       ...        \
# 31825      7.14       216.58     A        A3       ...
# 15707     11.99       333.60     B        B5       ...
# 39768      8.38       160.72     A        A5       ...
# 23243      9.62        38.51     B        B3       ...
# 26010     16.82       284.51     E        E2       ...
# 23207      9.99       161.45     B        B4       ...
# 22347      9.25       349.74     B        B2       ...
# 40417     13.98       187.93     C        C3       ...
# 25095     14.72        69.06     C        C5       ...
# 24898     11.49        98.92     B        B4       ...
# 9909       7.49        93.31     A        A4       ...
# 8173      13.49       135.73     C        C2       ...
# 25909     13.98       186.07     C        C3       ...
# 39272     11.03        98.26     C        C1       ...
# 3144       7.90       438.07     A        A4       ...
# 16968     10.00       484.01     B        B2       ...
# 5317      16.77       470.00     D        D2       ...
# 12631     13.49       575.12     C        C2       ...
# 31908     10.62       162.80     B        B3       ...
# 18226     11.11       262.33     B        B5       ...
# 15091     15.23       313.01     C        C5       ...
# 6985      14.27        93.64     C        C2       ...
# 9681       6.99        92.62     A        A3       ...
# 12735      9.99       419.42     B        B1       ...
# 25114     13.98       170.84     C        C3       ...
# 6568      15.27       287.19     C        C4       ...
# 5776      11.71       386.72     B        B3       ...
# 23571     10.36       810.92     B        B5       ...
# 23047     12.98       269.48     C        C3       ...
# 27504     13.98        51.26     C        C3       ...
# ...         ...          ...   ...       ...       ...
# 35216     15.31       313.34     D        D3       ...
# 42054     18.04       682.76     G        G4       ...
# 27390     17.56       251.55     E        E4       ...
# 14045     10.59       182.26     B        B2       ...
# 4556      11.71       694.60     B        B3       ...
# 35667     13.57       203.82     C        C3       ...
# 5244      20.89       134.96     F        F1       ...
# 16493     11.11        69.69     B        B5       ...
# 36682     12.84       201.71     C        C2       ...
# 27431     14.84       259.41     D        D1       ...
# 15677      9.99        74.35     B        B1       ...
# 12054     16.49       198.24     D        D3       ...
# 33025     14.26       514.59     C        C5       ...
# 75        14.65       413.94     C        C3       ...
# 37088     13.79       238.53     C        C5       ...
# 26204     11.12       491.94     B        B3       ...
# 33051     12.53       669.33     B        B5       ...
# 24322      9.99       395.22     B        B4       ...
# 35457     11.83       424.12     B        B3       ...
# 18620     14.17       186.86     C        C5       ...
# 39369      7.75       124.89     A        A3       ...
# 34147     13.22       730.10     C        C2       ...
# 22430      5.79       181.97     A        A2       ...
# 10311     15.99       263.65     D        D2       ...
# 9093      12.99       796.18     C        C1       ...
# 5151      15.27       287.19     C        C4       ...
# 6616      17.27       178.94     D        D3       ...
# 40874     13.92       327.72     C        C4       ...
# 37596     14.42       515.74     D        D2       ...
# 20631      7.66       218.26     A        A5       ...
#
#       hardship_payoff_balance_amount hardship_last_payment_amount  \
# 31825                            NaN                          NaN
# 15707                            NaN                          NaN
# 39768                            NaN                          NaN
# 23243                            NaN                          NaN
# 26010                            NaN                          NaN
# 23207                            NaN                          NaN
# 22347                            NaN                          NaN
# 40417                            NaN                          NaN
# 25095                            NaN                          NaN
# 24898                            NaN                          NaN
# 9909                             NaN                          NaN
# 8173                             NaN                          NaN
# 25909                            NaN                          NaN
# 39272                            NaN                          NaN
# 3144                             NaN                          NaN
# 16968                            NaN                          NaN
# 5317                             NaN                          NaN
# 12631                            NaN                          NaN
# 31908                            NaN                          NaN
# 18226                            NaN                          NaN
# 15091                            NaN                          NaN
# 6985                             NaN                          NaN
# 9681                             NaN                          NaN
# 12735                            NaN                          NaN
# 25114                            NaN                          NaN
# 6568                             NaN                          NaN
# 5776                             NaN                          NaN
# 23571                            NaN                          NaN
# 23047                            NaN                          NaN
# 27504                            NaN                          NaN
# ...                              ...                          ...
# 35216                            NaN                          NaN
# 42054                            NaN                          NaN
# 27390                            NaN                          NaN
# 14045                            NaN                          NaN
# 4556                             NaN                          NaN
# 35667                            NaN                          NaN
# 5244                             NaN                          NaN
# 16493                            NaN                          NaN
# 36682                            NaN                          NaN
# 27431                            NaN                          NaN
# 15677                            NaN                          NaN
# 12054                            NaN                          NaN
# 33025                            NaN                          NaN
# 75                               NaN                          NaN
# 37088                            NaN                          NaN
# 26204                            NaN                          NaN
# 33051                            NaN                          NaN
# 24322                            NaN                          NaN
# 35457                            NaN                          NaN
# 18620                            NaN                          NaN
# 39369                            NaN                          NaN
# 34147                            NaN                          NaN
# 22430                            NaN                          NaN
# 10311                            NaN                          NaN
# 9093                             NaN                          NaN
# 5151                             NaN                          NaN
# 6616                             NaN                          NaN
# 40874                            NaN                          NaN
# 37596                            NaN                          NaN
# 20631                            NaN                          NaN
#
#       disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 31825                Cash                     N                       NaN
# 15707                Cash                     N                       NaN
# 39768                Cash                     N                       NaN
# 23243                Cash                     N                       NaN
# 26010                Cash                     N                       NaN
# 23207                Cash                     N                       NaN
# 22347                Cash                     N                       NaN
# 40417                Cash                     N                       NaN
# 25095                Cash                     N                       NaN
# 24898                Cash                     N                       NaN
# 9909                 Cash                     N                       NaN
# 8173                 Cash                     N                       NaN
# 25909                Cash                     N                       NaN
# 39272                Cash                     N                       NaN
# 3144                 Cash                     N                       NaN
# 16968                Cash                     N                       NaN
# 5317                 Cash                     N                       NaN
# 12631                Cash                     N                       NaN
# 31908                Cash                     N                       NaN
# 18226                Cash                     N                       NaN
# 15091                Cash                     N                       NaN
# 6985                 Cash                     N                       NaN
# 9681                 Cash                     N                       NaN
# 12735                Cash                     N                       NaN
# 25114                Cash                     N                       NaN
# 6568                 Cash                     N                       NaN
# 5776                 Cash                     N                       NaN
# 23571                Cash                     N                       NaN
# 23047                Cash                     N                       NaN
# 27504                Cash                     N                       NaN
# ...                   ...                   ...                       ...
# 35216                Cash                     N                       NaN
# 42054                Cash                     N                       NaN
# 27390                Cash                     N                       NaN
# 14045                Cash                     N                       NaN
# 4556                 Cash                     N                       NaN
# 35667                Cash                     N                       NaN
# 5244                 Cash                     N                       NaN
# 16493                Cash                     N                       NaN
# 36682                Cash                     N                       NaN
# 27431                Cash                     N                       NaN
# 15677                Cash                     N                       NaN
# 12054                Cash                     N                       NaN
# 33025                Cash                     N                       NaN
# 75                   Cash                     N                       NaN
# 37088                Cash                     N                       NaN
# 26204                Cash                     N                       NaN
# 33051                Cash                     N                       NaN
# 24322                Cash                     N                       NaN
# 35457                Cash                     N                       NaN
# 18620                Cash                     N                       NaN
# 39369                Cash                     N                       NaN
# 34147                Cash                     N                       NaN
# 22430                Cash                     N                       NaN
# 10311                Cash                     N                       NaN
# 9093                 Cash                     N                       NaN
# 5151                 Cash                     N                       NaN
# 6616                 Cash                     N                       NaN
# 40874                Cash                     N                       NaN
# 37596                Cash                     N                       NaN
# 20631                Cash                     N                       NaN
#
#       settlement_status settlement_date settlement_amount  \
# 31825               NaN             NaN               NaN
# 15707               NaN             NaN               NaN
# 39768               NaN             NaN               NaN
# 23243               NaN             NaN               NaN
# 26010               NaN             NaN               NaN
# 23207               NaN             NaN               NaN
# 22347               NaN             NaN               NaN
# 40417               NaN             NaN               NaN
# 25095               NaN             NaN               NaN
# 24898               NaN             NaN               NaN
# 9909                NaN             NaN               NaN
# 8173                NaN             NaN               NaN
# 25909               NaN             NaN               NaN
# 39272               NaN             NaN               NaN
# 3144                NaN             NaN               NaN
# 16968               NaN             NaN               NaN
# 5317                NaN             NaN               NaN
# 12631               NaN             NaN               NaN
# 31908               NaN             NaN               NaN
# 18226               NaN             NaN               NaN
# 15091               NaN             NaN               NaN
# 6985                NaN             NaN               NaN
# 9681                NaN             NaN               NaN
# 12735               NaN             NaN               NaN
# 25114               NaN             NaN               NaN
# 6568                NaN             NaN               NaN
# 5776                NaN             NaN               NaN
# 23571               NaN             NaN               NaN
# 23047               NaN             NaN               NaN
# 27504               NaN             NaN               NaN
# ...                 ...             ...               ...
# 35216               NaN             NaN               NaN
# 42054               NaN             NaN               NaN
# 27390               NaN             NaN               NaN
# 14045               NaN             NaN               NaN
# 4556                NaN             NaN               NaN
# 35667               NaN             NaN               NaN
# 5244                NaN             NaN               NaN
# 16493               NaN             NaN               NaN
# 36682               NaN             NaN               NaN
# 27431               NaN             NaN               NaN
# 15677               NaN             NaN               NaN
# 12054               NaN             NaN               NaN
# 33025               NaN             NaN               NaN
# 75                  NaN             NaN               NaN
# 37088               NaN             NaN               NaN
# 26204               NaN             NaN               NaN
# 33051               NaN             NaN               NaN
# 24322               NaN             NaN               NaN
# 35457               NaN             NaN               NaN
# 18620               NaN             NaN               NaN
# 39369               NaN             NaN               NaN
# 34147               NaN             NaN               NaN
# 22430               NaN             NaN               NaN
# 10311               NaN             NaN               NaN
# 9093                NaN             NaN               NaN
# 5151                NaN             NaN               NaN
# 6616                NaN             NaN               NaN
# 40874               NaN             NaN               NaN
# 37596               NaN             NaN               NaN
# 20631               NaN             NaN               NaN
#
#        settlement_percentage settlement_term
# 31825                    NaN             NaN
# 15707                    NaN             NaN
# 39768                    NaN             NaN
# 23243                    NaN             NaN
# 26010                    NaN             NaN
# 23207                    NaN             NaN
# 22347                    NaN             NaN
# 40417                    NaN             NaN
# 25095                    NaN             NaN
# 24898                    NaN             NaN
# 9909                     NaN             NaN
# 8173                     NaN             NaN
# 25909                    NaN             NaN
# 39272                    NaN             NaN
# 3144                     NaN             NaN
# 16968                    NaN             NaN
# 5317                     NaN             NaN
# 12631                    NaN             NaN
# 31908                    NaN             NaN
# 18226                    NaN             NaN
# 15091                    NaN             NaN
# 6985                     NaN             NaN
# 9681                     NaN             NaN
# 12735                    NaN             NaN
# 25114                    NaN             NaN
# 6568                     NaN             NaN
# 5776                     NaN             NaN
# 23571                    NaN             NaN
# 23047                    NaN             NaN
# 27504                    NaN             NaN
# ...                      ...             ...
# 35216                    NaN             NaN
# 42054                    NaN             NaN
# 27390                    NaN             NaN
# 14045                    NaN             NaN
# 4556                     NaN             NaN
# 35667                    NaN             NaN
# 5244                     NaN             NaN
# 16493                    NaN             NaN
# 36682                    NaN             NaN
# 27431                    NaN             NaN
# 15677                    NaN             NaN
# 12054                    NaN             NaN
# 33025                    NaN             NaN
# 75                       NaN             NaN
# 37088                    NaN             NaN
# 26204                    NaN             NaN
# 33051                    NaN             NaN
# 24322                    NaN             NaN
# 35457                    NaN             NaN
# 18620                    NaN             NaN
# 39369                    NaN             NaN
# 34147                    NaN             NaN
# 22430                    NaN             NaN
# 10311                    NaN             NaN
# 9093                     NaN             NaN
# 5151                     NaN             NaN
# 6616                     NaN             NaN
# 40874                    NaN             NaN
# 37596                    NaN             NaN
# 20631                    NaN             NaN
#
# [100 rows x 145 columns]

# %% [markdown]
# ## Model

# %%
# Transform the data set, using keras_pandas
categorical_vars = ['term', 'grade', 'sub_grade', 'emp_length', 'home_ownership', 'verification_status', 'issue_d',
                    'pymnt_plan', 'purpose', 'addr_state', 'initial_list_status', 'application_type',
                    'disbursement_method', 'loan_status']
numerical_vars = ['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'annual_inc', 'installment', 'dti',
                  'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal', 'total_acc', 'pub_rec_bankruptcies',
                  'int_rate', 'revol_util']
text_vars = ['desc', 'title']

for categorical_var in categorical_vars:
    observations[categorical_var] = observations[categorical_var].fillna('None')
    observations[categorical_var] = observations[categorical_var].apply(str)
    
auto = Automater(categorical_vars=categorical_vars, numerical_vars=numerical_vars, text_vars=text_vars,
                 response_var='loan_status')

X, y = auto.fit_transform(observations)

# Start model with provided input nub
x = auto.input_nub

# Fill in your own hidden layers
x = Dense(8)(x)
x = Dense(16, activation='relu')(x)
x = Dense(8)(x)

# End model with provided output nub
x = auto.output_nub(x)

model = Model(inputs=auto.input_layers, outputs=x)
model.compile(optimizer='Adam', loss=auto.loss, metrics=['accuracy'])

# Train model
logging.warning('Settle in! This training normally takes about 5-20 minutes on CPU')
model.fit(X, y, epochs=1, validation_split=.2)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:95: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:128: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# WARNING:root:Settle in! This training normally takes about 5-20 minutes on CPU
# Train on 80 samples, validate on 20 samples
# Epoch 1/1
# 80/80 [==============================] - 2s 27ms/step - loss: 1.2729 - acc: 0.6375 - val_loss: 1.1723 - val_acc: 0.8500

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_term (InputLayer)         (None, 1)            0
# __________________________________________________________________________________________________
# input_grade (InputLayer)        (None, 1)            0
# __________________________________________________________________________________________________
# input_sub_grade (InputLayer)    (None, 1)            0
# __________________________________________________________________________________________________
# input_emp_length (InputLayer)   (None, 1)            0
# __________________________________________________________________________________________________
# input_home_ownership (InputLaye (None, 1)            0
# __________________________________________________________________________________________________
# input_verification_status (Inpu (None, 1)            0
# __________________________________________________________________________________________________
# input_issue_d (InputLayer)      (None, 1)            0
# __________________________________________________________________________________________________
# input_pymnt_plan (InputLayer)   (None, 1)            0
# __________________________________________________________________________________________________
# input_purpose (InputLayer)      (None, 1)            0
# __________________________________________________________________________________________________
# input_addr_state (InputLayer)   (None, 1)            0
# __________________________________________________________________________________________________
# input_initial_list_status (Inpu (None, 1)            0
# __________________________________________________________________________________________________
# input_application_type (InputLa (None, 1)            0
# __________________________________________________________________________________________________
# input_disbursement_method (Inpu (None, 1)            0
# __________________________________________________________________________________________________
# input_desc (InputLayer)         (None, 27)           0
# __________________________________________________________________________________________________
# input_title (InputLayer)        (None, 2)            0
# __________________________________________________________________________________________________
# embedding_term (Embedding)      (None, 1, 2)         6           input_term[0][0]
# __________________________________________________________________________________________________
# embedding_grade (Embedding)     (None, 1, 4)         32          input_grade[0][0]
# __________________________________________________________________________________________________
# embedding_sub_grade (Embedding) (None, 1, 14)        378         input_sub_grade[0][0]
# __________________________________________________________________________________________________
# embedding_emp_length (Embedding (None, 1, 7)         91          input_emp_length[0][0]
# __________________________________________________________________________________________________
# embedding_home_ownership (Embed (None, 1, 3)         15          input_home_ownership[0][0]
# __________________________________________________________________________________________________
# embedding_verification_status ( (None, 1, 2)         8           input_verification_status[0][0]
# __________________________________________________________________________________________________
# embedding_issue_d (Embedding)   (None, 1, 18)        630         input_issue_d[0][0]
# __________________________________________________________________________________________________
# embedding_pymnt_plan (Embedding (None, 1, 1)         2           input_pymnt_plan[0][0]
# __________________________________________________________________________________________________
# embedding_purpose (Embedding)   (None, 1, 7)         98          input_purpose[0][0]
# __________________________________________________________________________________________________
# embedding_addr_state (Embedding (None, 1, 15)        450         input_addr_state[0][0]
# __________________________________________________________________________________________________
# embedding_initial_list_status ( (None, 1, 1)         2           input_initial_list_status[0][0]
# __________________________________________________________________________________________________
# embedding_application_type (Emb (None, 1, 1)         2           input_application_type[0][0]
# __________________________________________________________________________________________________
# embedding_disbursement_method ( (None, 1, 1)         2           input_disbursement_method[0][0]
# __________________________________________________________________________________________________
# embedding_desc (Embedding)      (None, 27, 200)      221200      input_desc[0][0]
# __________________________________________________________________________________________________
# embedding_title (Embedding)     (None, 2, 200)       212200      input_title[0][0]
# __________________________________________________________________________________________________
# input_loan_amnt (InputLayer)    (None, 1)            0
# __________________________________________________________________________________________________
# input_funded_amnt (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# input_funded_amnt_inv (InputLay (None, 1)            0
# __________________________________________________________________________________________________
# input_annual_inc (InputLayer)   (None, 1)            0
# __________________________________________________________________________________________________
# input_installment (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# input_dti (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_inq_last_6mths (InputLaye (None, 1)            0
# __________________________________________________________________________________________________
# input_open_acc (InputLayer)     (None, 1)            0
# __________________________________________________________________________________________________
# input_pub_rec (InputLayer)      (None, 1)            0
# __________________________________________________________________________________________________
# input_revol_bal (InputLayer)    (None, 1)            0
# __________________________________________________________________________________________________
# input_total_acc (InputLayer)    (None, 1)            0
# __________________________________________________________________________________________________
# input_pub_rec_bankruptcies (Inp (None, 1)            0
# __________________________________________________________________________________________________
# input_int_rate (InputLayer)     (None, 1)            0
# __________________________________________________________________________________________________
# input_revol_util (InputLayer)   (None, 1)            0
# __________________________________________________________________________________________________
# flatten_embedding_term (Flatten (None, 2)            0           embedding_term[0][0]
# __________________________________________________________________________________________________
# flatten_embedding_grade (Flatte (None, 4)            0           embedding_grade[0][0]
# __________________________________________________________________________________________________
# flatten_embedding_sub_grade (Fl (None, 14)           0           embedding_sub_grade[0][0]
# __________________________________________________________________________________________________
# flatten_embedding_emp_length (F (None, 7)            0           embedding_emp_length[0][0]
# __________________________________________________________________________________________________
# flatten_embedding_home_ownershi (None, 3)            0           embedding_home_ownership[0][0]
# __________________________________________________________________________________________________
# flatten_embedding_verification_ (None, 2)            0           embedding_verification_status[0][
# __________________________________________________________________________________________________
# flatten_embedding_issue_d (Flat (None, 18)           0           embedding_issue_d[0][0]
# __________________________________________________________________________________________________
# flatten_embedding_pymnt_plan (F (None, 1)            0           embedding_pymnt_plan[0][0]
# __________________________________________________________________________________________________
# flatten_embedding_purpose (Flat (None, 7)            0           embedding_purpose[0][0]
# __________________________________________________________________________________________________
# flatten_embedding_addr_state (F (None, 15)           0           embedding_addr_state[0][0]
# __________________________________________________________________________________________________
# flatten_embedding_initial_list_ (None, 1)            0           embedding_initial_list_status[0][
# __________________________________________________________________________________________________
# flatten_embedding_application_t (None, 1)            0           embedding_application_type[0][0]
# __________________________________________________________________________________________________
# flatten_embedding_disbursement_ (None, 1)            0           embedding_disbursement_method[0][
# __________________________________________________________________________________________________
# bidirectiona_lstm_desc (Bidirec (None, 256)          336896      embedding_desc[0][0]
# __________________________________________________________________________________________________
# bidirectiona_lstm_title (Bidire (None, 256)          336896      embedding_title[0][0]
# __________________________________________________________________________________________________
# concatenate_inputs (Concatenate (None, 602)          0           input_loan_amnt[0][0]
#                                                                  input_funded_amnt[0][0]
#                                                                  input_funded_amnt_inv[0][0]
#                                                                  input_annual_inc[0][0]
#                                                                  input_installment[0][0]
#                                                                  input_dti[0][0]
#                                                                  input_inq_last_6mths[0][0]
#                                                                  input_open_acc[0][0]
#                                                                  input_pub_rec[0][0]
#                                                                  input_revol_bal[0][0]
#                                                                  input_total_acc[0][0]
#                                                                  input_pub_rec_bankruptcies[0][0]
#                                                                  input_int_rate[0][0]
#                                                                  input_revol_util[0][0]
#                                                                  flatten_embedding_term[0][0]
#                                                                  flatten_embedding_grade[0][0]
#                                                                  flatten_embedding_sub_grade[0][0]
#                                                                  flatten_embedding_emp_length[0][0
#                                                                  flatten_embedding_home_ownership[
#                                                                  flatten_embedding_verification_st
#                                                                  flatten_embedding_issue_d[0][0]
#                                                                  flatten_embedding_pymnt_plan[0][0
#                                                                  flatten_embedding_purpose[0][0]
#                                                                  flatten_embedding_addr_state[0][0
#                                                                  flatten_embedding_initial_list_st
#                                                                  flatten_embedding_application_typ
#                                                                  flatten_embedding_disbursement_me
#                                                                  bidirectiona_lstm_desc[0][0]
#                                                                  bidirectiona_lstm_title[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 8)            4824        concatenate_inputs[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 16)           144         dense_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 8)            136         dense_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 4)            36          dense_4[0][0]
# ==================================================================================================
# Total params: 1,114,048
# Trainable params: 1,114,048
# Non-trainable params: 0
# __________________________________________________________________________________________________
